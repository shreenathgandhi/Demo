# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopword_list = set(stopwords.words('english'))

# %%
#Configure image
bg_color = "#101010"

'''enter values for the image height and width:
img_height = #Todo
img_width = #Todo
'''

# %%
''' If you are using google collab, use this to upload your text file!
from google.colab import files
uploaded = files.upload()'''

# %%
#Read words from the file
'''Enter the appropriate file name 
with open("Todo", "r") as f:
    input_words = f.read().split()
'''

# %%
'''ToDo("Define data as a dictionary data type")'''

# %%
#Filter out the stop words
for word in input_words:
    word = word.lower()
    if word in stopword_list:
        continue
    data[word] = data.get(word, 0) + 1

# %%
#Create the word cloud
from wordcloud import WordCloud
word_cloud = WordCloud(
    background_color = bg_color,
    width = img_width,
    height = img_height
)

# %%
word_cloud.generate_from_frequencies(data)

# %%
word_cloud.to_file('image.png')
